# %%
from PIL import Image

import numpy as np

# %%
pil_img = Image.open("RGB.png")

# %%
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x7FAA8AF19210>

# %%
img = np.array(pil_img)

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
import matplotlib.pyplot as plt

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
red = img[:, :, 0]
green = img[:, :, 1]
blue = img[:, :, 2]

# %%
plt.imshow(red)

# %%
plt.imshow(green, cmap="gray")

# %%
plt.imshow(blue, cmap="gray")
