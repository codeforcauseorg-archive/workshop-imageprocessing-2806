# %%
from PIL import Image

import numpy as np

# %%
pil_img = Image.open("thor.jpg")

# %%
pil_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x381 at 0x7FF0D3F17090>

# %%
img = np.array(pil_img)

# %%
img.shape
# Out:
# (381, 678, 3)

# %%
import matplotlib.pyplot as plt

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow
# Out:
# array([[[ 18,  45,  38],
#         [ 18,  45,  38],
#         [ 18,  43,  37],
#         ...,
#         [ 96,  95,  93],
#         [ 97,  93,  92],
#         [ 95,  89,  89]],
#
#        [[ 22,  49,  44],
#         [ 21,  48,  43],
#         [ 22,  47,  43],
#         ...,
#         [ 96,  95,  93],
#         [ 98,  92,  92],
#         [ 97,  88,  89]],
#
#        [[ 28,  55,  50],
#         [ 28,  55,  50],
#         [ 28,  53,  49],
#         ...,
#         [102,  98,  95],
#         [104,  96,  94],
#         [102,  92,  91]],
#
#        ...,
#
#        [[ 24,  44,  45],
#         [ 24,  44,  45],
#         [ 24,  44,  45],
#         ...,
#         [ 47,  28,  22],
#         [ 46,  27,  21],
#         [ 46,  27,  21]],
#
#        [[ 22,  43,  44],
#         [ 22,  43,  44],
#         [ 22,  43,  44],
#         ...,
#         [ 45,  26,  20],
#         [ 45,  26,  20],
#         [ 44,  25,  19]],
#
#        [[ 22,  43,  44],
#         [ 22,  43,  44],
#         [ 22,  43,  44],
# ...
